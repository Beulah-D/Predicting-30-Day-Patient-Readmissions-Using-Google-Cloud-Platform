# %%
import pandas as pd
import numpy as np

# %%
predictions_path = 'gs://healthcare_readmissions/853819008626/healthcare-readmissions-inference-pipeline-20241218004423/perform-predictions_6976501368156585984/predictions_path'
predictions = pd.read_csv(predictions_path)

# %%
predictions
# Out:
#       PatientID  readmission_prediction
# 0       1000001                       0
# 1       1000007                       0
# 2       1000011                       1
# 3       1000012                       0
# 4       1000033                       1
# ...         ...                     ...
# 1957    1009989                       1
# 1958    1009993                       0
# 1959    1009995                       0
# 1960    1009996                       1
# 1961    1009997                       1
#
# [1962 rows x 2 columns]

# %%
predictions.to_csv('my_predictions.csv', index=False)

from google.colab import files
files.download('my_predictions.csv')
